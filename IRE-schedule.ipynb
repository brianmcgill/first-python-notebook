# %%
import pandas as pd

# %%
sched = pd.read_csv("https://raw.githubusercontent.com/tommeagher/irescraper/master/ire2017sched.csv")

# %%
sched
# Out:
#             Topic                                            Subject  \
# 0             NaN  (More than) 10 data sources you may never have...
# 1             NaN                   IRE Conference Sales (Wednesday)
# 2             NaN            IRE Conference Registration (Wednesday)
# 3             NaN                    IRE Conference Sales (Thursday)
# 4             NaN             IRE Conference Registration (Thursday)
# 5             NaN       Following the money (Sponsored by Bloomberg)
# 6    spreadsheets         Excel 1: Getting started with spreadsheets
# 7             NaN                 Exhibitors & Recruiters (Thursday)
# 8             NaN  Best of broadcast  (Sponsored by National Asso...
# 9             NaN  Show & Tell *Thursday #1 (Sponsored by Napoli ...
# 10            NaN  Prisons and jails (Sponsored by Criminal Justi...
# 11            NaN               Exhibitor/Recruiter Hours (Thursday)
# 12            NaN                    Investigating the tech industry
# ...

# %%
sched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 10 columns):
# Topic          28 non-null object
# Subject        245 non-null object
# Start Date     245 non-null object
# Start Time     245 non-null object
# End Date       245 non-null object
# End Time       245 non-null object
# Speaker(s)     245 non-null object
# Description    233 non-null object
# Location       245 non-null object
# URL            245 non-null object
# dtypes: object(10)
# memory usage: 19.2+ KB

# %%
sched.Location.value_counts()
# Out:
# Grand Canyon 9-10                            20
# Grand Canyon 4-5                             19
# Grand Canyon 1-3                             19
# Grand Canyon 11-13                           19
# Grand Sonoran B-D                            18
# Pinnacle Peak 2                              17
# Grand Sonoran G                              16
# Grand Canyon 8                               16
# Grand Canyon 7                               16
# Grand Canyon 6                               16
# Pinnacle Peak 1                              16
# IRE Commons                                  15
# Pinnacle Peak 3                               6
# Grand Sonoran F Foyer                         5
# East registration desk                        4
# Foyer - 1st floor meeting space               3
# Pinnacle 2                                    3
# Grand Canyon Foyer                            3
# Grand Sonoran E                               3
# Grand Canyon 6-8                              2
# ...
